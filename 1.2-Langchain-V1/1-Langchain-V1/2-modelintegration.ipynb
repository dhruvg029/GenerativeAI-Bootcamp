# %% [markdown]
# ### Models Integration With OpenAI, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

## Import the API keys for processing the LLM models
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
os.environ["GROQ_API_KEY"] = os.getenv("GROQ_API_KEY")

# %%
from langchain.chat_models import init_chat_model

## Groq chat integration using chat model
model = init_chat_model(
    model = "llama-3.3-70b-versatile", 
    model_provider="groq"
)

model
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x0000020053935450>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x0000020053935E50>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
## invoke the model
response=model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm always happy to chat and help with any questions or topics you'd like to discuss. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 40, 'total_tokens': 103, 'completion_time': 0.1352446, 'completion_tokens_details': None, 'prompt_time': 0.001709243, 'prompt_tokens_details': None, 'queue_time': 0.193144712, 'total_time': 0.136953843}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_0761e44d7b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--65ce32f2-0629-4bc5-b253-254794448726-0', usage_metadata={'input_tokens': 40, 'output_tokens': 63, 'total_tokens': 103})

# %%
import os
from langchain_groq import ChatGroq

## Import ChatGroq LLM for chatbot
model = ChatGroq(model="llama-3.3-70b-versatile")
response = model.invoke("Hello How are you?")
response
# Out:
# AIMessage(content="Hello! I'm doing well, thanks for asking. I'm a large language model, so I don't have feelings or emotions like humans do, but I'm always happy to chat and help with any questions or topics you'd like to discuss. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 63, 'prompt_tokens': 40, 'total_tokens': 103, 'completion_time': 0.142420131, 'completion_tokens_details': None, 'prompt_time': 0.009203435, 'prompt_tokens_details': None, 'queue_time': 0.048018031, 'total_time': 0.151623566}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_f8b414701e', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--5a154bd5-9d11-43c2-8c7d-d5ec351cddda-0', usage_metadata={'input_tokens': 40, 'output_tokens': 63, 'total_tokens': 103})

# %% [markdown]
# ### Google Gemini Model Integration

# %%
import os
from langchain.chat_models import init_chat_model

## Loading the google LLM for chatbot
model = init_chat_model("google_genai:gemini-2.5-flash")
response = model.invoke("Why do parrots talk?")
response.content
# Out:
# 'Parrots talk primarily because they are highly intelligent, social animals with a unique vocal learning ability. It\'s important to clarify that while they can mimic human speech remarkably well, they don\'t "talk" in the same way humans do, understanding the nuances of language. Instead, it\'s a sophisticated form of mimicry driven by several factors:\n\n1.  **Social Bonding and Integration:**\n    *   **Flock Animals:** In the wild, parrots live in complex social structures called flocks. Vocalizations are crucial for communication within these flocks – identifying individuals, warning of predators, coordinating movements, and reinforcing social bonds.\n    *   **Fitting In:** When a parrot lives with humans, it often perceives its human companions as its "flock." Mimicking human speech can be their way of trying to fit in, communicate, and bond with their adopted social group. They are trying to "speak the language" of their flock.\n\n2.  **Intelligence and Vocal Learning:**\n   
# ...

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

## ChatGoogleGenerativeAI for chatbot and including the model
model = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")
response = model.invoke("Why do parrots talk?")
response
# Out:
# AIMessage(content='Parrots talk for a fascinating combination of reasons, stemming from their intelligence, social nature, and evolutionary adaptations. It\'s not just about mimicking sounds; it\'s a complex behavior with multiple driving forces.\n\nHere\'s a breakdown of why parrots "talk":\n\n**1. Social Bonding and Communication:**\n\n*   **Flock Animals:** Parrots are highly social creatures that live in large flocks in the wild. Communication is vital for their survival, allowing them to coordinate movements, warn of predators, find food sources, and maintain group cohesion.\n*   **Mimicry as Social Glue:** In their natural environment, parrots often mimic the calls of other parrots within their flock. This mimicry helps them to:\n    *   **Identify flock members:** Recognizing individual calls strengthens social bonds.\n    *   **Integrate into the group:** By learning and using the group\'s vocalizations, a parrot signals its belonging and acceptance.\n    *   **Strengthen soc
# ...

# %% [markdown]
# ### Streaming And Batch
#
# ### Streaming
# Most models can stream their output content while it is being generated. By displaying output progressively, streaming significantly improves user experience, particularly for longer responses.
# Calling stream() returns an iterator that yields output chunks as they are produced. You can use a loop to process each chunk in real-time:

# %%
model.invoke("Write me a 200 words paragraph on Artificial Intelligence")
# Out:
# AIMessage(content='Artificial Intelligence (AI) has revolutionized the way we live, work, and interact with technology. It refers to the development of computer systems that can perform tasks that typically require human intelligence, such as learning, problem-solving, and decision-making. AI has numerous applications across various industries, including healthcare, finance, transportation, and education. In healthcare, AI-powered algorithms can analyze medical images and diagnose diseases more accurately and quickly than human doctors. In finance, AI-driven systems can detect fraudulent transactions and predict market trends. Self-driving cars, powered by AI, are being tested on roads, promising to reduce accidents and improve traffic flow. Moreover, AI-powered virtual assistants, such as Siri and Alexa, have become an integral part of our daily lives, making it easier to manage our schedules, play music, and control our smart home devices. As AI continues to advance, we can expect 
# ...

# %%
for chunk in model.stream("Write me a 200 words paragraph on Artificial Intelligence"):
    print(chunk.text, end="|", flush=True)
# Out:
# |Art|ificial| Intelligence| (|AI|)| has| revolution|ized| the| way| we| live|,| work|,| and| interact| with| technology|.| It| refers| to| the| development| of| computer| systems| that| can| perform| tasks| that| typically| require| human| intelligence|,| such| as| learning|,| problem|-solving|,| and| decision|-making|.| AI| systems| use| algorithms| and| data| to| make| predictions|,| classify| objects|,| and| generate| insights|,| enabling| them| to| automate| complex| tasks| and| improve| efficiency|.| From| virtual| assistants| like| Siri| and| Alexa| to| self|-driving| cars| and| personalized| product| recommendations|,| AI| is| increasingly| ubiquitous| in| our| daily| lives|.| Moreover|,| AI| has| the| potential| to| transform| industries| such| as| healthcare|,| finance|,| and| education|,| by| providing| accurate| diagnoses|,| detecting| fraud|,| and| creating| personalized| learning| experiences|.| As| AI| continues| to| evolve| and| improve|,| it| is| likely| to| have| a| 
# ...

# %%
model.invoke("Why do parrots have colorful feathers?")
# Out:
# AIMessage(content="Parrots have colorful feathers for several reasons, including:\n\n1. **Communication and Social Signaling**: Bright colors help parrots communicate with each other, especially during courtship, mating, and territorial displays. Different colors can signal a parrot's sex, age, health, and social status.\n2. **Camouflage and Defense**: While it may seem counterintuitive, some parrots' bright colors can actually serve as camouflage in their natural habitats. For example, the vibrant plumage of some parrots can blend in with the bright colors of flowers, fruits, or sunlit foliage, making it harder for predators to spot them.\n3. **Mating and Attraction**: Colorful feathers can be an attractive feature for potential mates. Parrots with more vibrant, intense, or rare colors may be more desirable to mates, which can lead to better reproductive opportunities.\n4. **Thermoregulation**: Some research suggests that the structure and color of parrot feathers can help regulate 
# ...

# %%
for chunk in model.stream("Why do parrots have colorful feathers?"):
    print(chunk.text, end="|", flush=True)
# Out:
# |Par|rots| have| colorful| feathers| for| several| reasons|,| including|:
#
# |1|.| **|M|ating| and| At|traction|**:| Vibr|ant| plum|age| helps| par|rots| attract| potential| mates|.| The| brighter| and| more| intense| the| colors|,| the| more| attractive| the| bird| appears| to| the| opposite| sex|.| This| is| especially| true| for| male| par|rots|,| who| often| have| more| elaborate| and| colorful| feathers| than| females|.
# |2|.| **|Communication| and| Social| Status|**:| Color|ful| feathers| can| convey| information| about| a| par|rot|'s| social| status|,| age|,| sex|,| and| even| its| health|.| For| example|,| some| par|rot| species| have| specific| color| patterns| that| indicate| dominance| or| submission|.
# ...

# %% [markdown]
# #### Batch
# Batching a collection of independent requests to a model can significantly improve performance and reduce costs, as the processing can be done in parallel:

# %%
## Use .batch() function to provide a list of questions that LLM can output
responses = model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
])
for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers for several reasons, which can be broadly categorized into communication, mating, camouflage, and thermoregulation. Here are some of the main purposes of their vibrant plumage:\n\n1. **Communication and Social Signaling**: Parrots use their colorful feathers to convey information and express emotions. They can signal aggression, courtship, or friendship through specific color displays. For example, some parrot species will raise their brightly colored crests or fans to signal dominance or attract a mate.\n2. **Mating and Attraction**: Bright colors can be an attractive feature for potential mates. In many parrot species, males have more vibrant plumage than females, which helps them stand out and demonstrate their suitability as a partner. The brighter the colors, the healthier and more desirable the individual may appear.\n3. **Camouflage and Disguise**: While it may seem counterintuitive, some parrots' colorful feathers can actually help them
# ...

# %%
model.batch(
    ["Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"],
    config={
        'max_concurrency': 5,  ## Limit to 5 parallel calls
    }
)
# Out:
# [AIMessage(content="Parrots have colorful feathers for several reasons, including:\n\n1. **Communication and Signaling**: Bright colors can serve as a form of non-verbal communication, helping parrots to signal their species, sex, age, and reproductive status to other birds. For example, some parrot species have brightly colored heads or beaks that indicate their dominance or attractiveness to potential mates.\n2. **Mating and Courtship**: Vibrant feathers can play a crucial role in attracting a mate. Many parrot species exhibit elaborate courtship displays, which involve displaying their colorful plumage to potential partners. The brightness and intensity of the colors can indicate the bird's health, fitness, and genetic quality.\n3. **Camouflage and Protection**: While it may seem counterintuitive, some parrots' bright colors can actually serve as a form of camouflage. For example, the bright green feathers of some parrot species can help them blend in with their tropical rainfores
# ...
