# %% [markdown]
# ### Chatbots With LangGraph

# %%
# %pip install langgraph langsmith
# Out:
# Collecting langgraph
#   Using cached langgraph-1.2.2-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: langsmith in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.8.8)
# Requirement already satisfied: langchain-core<2,>=1.4.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph) (1.4.0)
# Collecting langgraph-checkpoint<5.0.0,>=4.1.0 (from langgraph)
#   Using cached langgraph_checkpoint-4.1.1-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-prebuilt<1.2.0,>=1.1.0 (from langgraph)
#   Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph)
#   Using cached langgraph_sdk-0.3.15-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pydantic>=2.7.4 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph) (3.7.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2,>=1.4.0->langgraph) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2,>=1.4.0->langgraph) (0.0.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2,>=1.4.0->langgraph) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2,>=1.4.0->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2,>=1.4.0->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2,>=1.4.0->langgraph) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2,>=1.4.0->langgraph) (0.16.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith) (16.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->langsmith) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->langsmith) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->langsmith) (1.0.9)
# Requirement already satisfied: idna in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->langsmith) (3.17)
# Requirement already satisfied: h11>=0.16 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.0->langgraph) (3.1.1)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph)
#   Downloading ormsgpack-1.12.2-cp314-cp314-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith) (2.7.0)
# Using cached langgraph-1.2.2-py3-none-any.whl (236 kB)
# Using cached langgraph_checkpoint-4.1.1-py3-none-any.whl (56 kB)
# Using cached langgraph_prebuilt-1.1.0-py3-none-any.whl (41 kB)
# Using cached langgraph_sdk-0.3.15-py3-none-any.whl (98 kB)
# Downloading ormsgpack-1.12.2-cp314-cp314-win_amd64.whl (117 kB)
# Installing collected packages: ormsgpack, langgraph-sdk, langgraph-checkpoint, langgraph-prebuilt, langgraph
#
#    ---------------------------------------- 0/5 [ormsgpack]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    -------- ------------------------------- 1/5 [langgraph-sdk]
#    ---------------- ----------------------- 2/5 [langgraph-checkpoint]
#    ---------------- ----------------------- 2/5 [langgraph-checkpoint]
#    ---------------- ----------------------- 2/5 [langgraph-checkpoint]
#    ---------------- ----------------------- 2/5 [langgraph-checkpoint]
#    ---------------- ----------------------- 2/5 [langgraph-checkpoint]
#    ---------------- ----------------------- 2/5 [langgraph-checkpoint]
#    ---------------- ----------------------- 2/5 [langgraph-checkpoint]
#    ---------------- ----------------------- 2/5 [langgraph-checkpoint]
#    ------------------------ --------------- 3/5 [langgraph-prebuilt]
#    ------------------------ --------------- 3/5 [langgraph-prebuilt]
#    ------------------------ --------------- 3/5 [langgraph-prebuilt]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    -------------------------------- ------- 4/5 [langgraph]
#    ---------------------------------------- 5/5 [langgraph]
#
# Successfully installed langgraph-1.2.2 langgraph-checkpoint-4.1.1 langgraph-prebuilt-1.1.0 langgraph-sdk-0.3.15 ormsgpack-1.12.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %%
# %pip install langchain langchain_groq langchain_community
# Out:
# Collecting langchain
#   Using cached langchain-1.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain_groq in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.1.2)
# Collecting langchain_community
#   Using cached langchain_community-0.4.2-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain) (1.4.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain) (1.2.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain) (2.13.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.14 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.0.16)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.8.8)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.4.0->langchain) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.0->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (0.3.15)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph<1.3.0,>=1.2.2->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.2->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.34.2)
# Requirement already satisfied: websockets>=15.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (16.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (0.25.0)
# Requirement already satisfied: anyio in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (1.0.9)
# Requirement already satisfied: idna in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (3.17)
# Requirement already satisfied: h11>=0.16 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.3.0,>=1.2.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: groq<1.0.0,>=0.30.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain_groq) (0.37.1)
# Requirement already satisfied: distro<2,>=1.7.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.9.0)
# Requirement already satisfied: sniffio in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from groq<1.0.0,>=0.30.0->langchain_groq) (1.3.1)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain_community)
#   Downloading aiohttp-3.13.5-cp314-cp314-win_amd64.whl.metadata (8.4 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain_community)
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting langchain-classic<2.0.0,>=1.0.7 (from langchain_community)
#   Using cached langchain_classic-1.0.7-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain_community) (2.4.6)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain_community)
#   Using cached pydantic_settings-2.14.1-py3-none-any.whl.metadata (3.4 kB)
# Collecting sqlalchemy<3.0.0,>=1.4.0 (from langchain_community)
#   Downloading sqlalchemy-2.0.50-cp314-cp314-win_amd64.whl.metadata (9.8 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiohappyeyeballs-2.6.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading propcache-0.5.2-cp314-cp314-win_amd64.whl.metadata (17 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain_community)
#   Downloading yarl-1.24.2-cp314-cp314-win_amd64.whl.metadata (97 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.2 (from langchain-classic<2.0.0,>=1.0.7->langchain_community)
#   Using cached langchain_text_splitters-1.1.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting python-dotenv>=0.21.0 (from pydantic-settings<3.0.0,>=2.10.1->langchain_community)
#   Using cached python_dotenv-1.2.2-py3-none-any.whl.metadata (27 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.0->langchain) (2.7.0)
# Collecting greenlet>=1 (from sqlalchemy<3.0.0,>=1.4.0->langchain_community)
#   Downloading greenlet-3.5.1-cp314-cp314-win_amd64.whl.metadata (3.9 kB)
# Using cached langchain-1.3.2-py3-none-any.whl (121 kB)
# Using cached langchain_community-0.4.2-py3-none-any.whl (2.4 MB)
# Downloading aiohttp-3.13.5-cp314-cp314-win_amd64.whl (464 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached langchain_classic-1.0.7-py3-none-any.whl (1.0 MB)
# Using cached langchain_text_splitters-1.1.2-py3-none-any.whl (35 kB)
# Downloading multidict-6.7.1-cp314-cp314-win_amd64.whl (45 kB)
# Using cached pydantic_settings-2.14.1-py3-none-any.whl (60 kB)
# Downloading sqlalchemy-2.0.50-cp314-cp314-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    ---------------------------------------  2.1/2.1 MB 11.8 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 7.5 MB/s  0:00:00
# Downloading yarl-1.24.2-cp314-cp314-win_amd64.whl (94 kB)
# Using cached aiohappyeyeballs-2.6.2-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading frozenlist-1.8.0-cp314-cp314-win_amd64.whl (44 kB)
# Downloading greenlet-3.5.1-cp314-cp314-win_amd64.whl (239 kB)
# Downloading propcache-0.5.2-cp314-cp314-win_amd64.whl (42 kB)
# Using cached python_dotenv-1.2.2-py3-none-any.whl (22 kB)
# Installing collected packages: python-dotenv, propcache, multidict, httpx-sse, greenlet, frozenlist, aiohappyeyeballs, yarl, sqlalchemy, aiosignal, pydantic-settings, aiohttp, langchain-text-splitters, langchain-classic, langchain_community, langchain
#
#    ----------------------------------------  0/16 [python-dotenv]
#    ----------------------------------------  0/16 [python-dotenv]
#    ----------------------------------------  0/16 [python-dotenv]
#    ----------------------------------------  0/16 [python-dotenv]
#    ----------------------------------------  0/16 [python-dotenv]
#    -- -------------------------------------  1/16 [propcache]
#    -- -------------------------------------  1/16 [propcache]
#    ----- ----------------------------------  2/16 [multidict]
#    ----- ----------------------------------  2/16 [multidict]
#    ----- ----------------------------------  2/16 [multidict]
#    ------- --------------------------------  3/16 [httpx-sse]
#    ------- --------------------------------  3/16 [httpx-sse]
#    ---------- -----------------------------  4/16 [greenlet]
#    ---------- -----------------------------  4/16 [greenlet]
#    ---------- -----------------------------  4/16 [greenlet]
#    ---------- -----------------------------  4/16 [greenlet]
#    ---------- -----------------------------  4/16 [greenlet]
#    ---------- -----------------------------  4/16 [greenlet]
#    ---------- -----------------------------  4/16 [greenlet]
#    ---------- -----------------------------  4/16 [greenlet]
#    ---------- -----------------------------  4/16 [greenlet]
#    ---------- -----------------------------  4/16 [greenlet]
#    ---------- -----------------------------  4/16 [greenlet]
#    ------------ ---------------------------  5/16 [frozenlist]
#    --------------- ------------------------  6/16 [aiohappyeyeballs]
#    --------------- ------------------------  6/16 [aiohappyeyeballs]
#    ----------------- ----------------------  7/16 [yarl]
#    ----------------- ----------------------  7/16 [yarl]
#    ----------------- ----------------------  7/16 [yarl]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    -------------------- -------------------  8/16 [sqlalchemy]
#    ---------------------- -----------------  9/16 [aiosignal]
#    ------------------------- -------------- 10/16 [pydantic-settings]
#    ------------------------- -------------- 10/16 [pydantic-settings]
#    ------------------------- -------------- 10/16 [pydantic-settings]
#    ------------------------- -------------- 10/16 [pydantic-settings]
#    ------------------------- -------------- 10/16 [pydantic-settings]
#    ------------------------- -------------- 10/16 [pydantic-settings]
#    ------------------------- -------------- 10/16 [pydantic-settings]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    --------------------------- ------------ 11/16 [aiohttp]
#    ------------------------------ --------- 12/16 [langchain-text-splitters]
#    ------------------------------ --------- 12/16 [langchain-text-splitters]
#    ------------------------------ --------- 12/16 [langchain-text-splitters]
#    ------------------------------ --------- 12/16 [langchain-text-splitters]
#    ------------------------------ --------- 12/16 [langchain-text-splitters]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    -------------------------------- ------- 13/16 [langchain-classic]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ----------------------------------- ---- 14/16 [langchain_community]
#    ------------------------------------- -- 15/16 [langchain]
#    ------------------------------------- -- 15/16 [langchain]
#    ------------------------------------- -- 15/16 [langchain]
#    ------------------------------------- -- 15/16 [langchain]
#    ------------------------------------- -- 15/16 [langchain]
#    ------------------------------------- -- 15/16 [langchain]
#    ---------------------------------------- 16/16 [langchain]
#
# Successfully installed aiohappyeyeballs-2.6.2 aiohttp-3.13.5 aiosignal-1.4.0 frozenlist-1.8.0 greenlet-3.5.1 httpx-sse-0.4.3 langchain-1.3.2 langchain-classic-1.0.7 langchain-text-splitters-1.1.2 langchain_community-0.4.2 multidict-6.7.1 propcache-0.5.2 pydantic-settings-2.14.1 python-dotenv-1.2.2 sqlalchemy-2.0.50 yarl-1.24.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored
# WARNING: Cache entry deserialization failed, entry ignored

# %%
import os

langsmith = "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"
groq_api_key = "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"

# groq_api_key = os.getenv('groq_api_key')
# langsmith = os.getenv('LANGSMITH_API_KEY')

print(langsmith)

os.environ["LANGCHAIN_API_KEY"] = langsmith
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_PROJECT"] = "LangGraphTesting"
# Out:
# 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

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model = "llama-3.3-70b-versatile", api_key = groq_api_key, temperature = 0)
llm
# Out:
# ChatGroq(output_version=None, profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x000002CF4C10F890>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x000002CF4C29C2D0>, model_name='llama-3.3-70b-versatile', temperature=1e-08, model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %% [markdown]
# ## Start Building Chatbot Using Langgraph

# %%
from typing import Annotated
from typing_extensions import TypedDict
from langgraph.graph import StateGraph,START,END
from langgraph.graph.message import add_messages

class State(TypedDict):
    ## Messages have the type "list". The `add_messages` function
    ## in the annotation defines how this state key should be updated
    ## (in this case, it appends messages to the list, rather than overwriting them)
  messages:Annotated[list,add_messages]

graph_builder = StateGraph(State)
graph_builder

# %%
def chatbot(state:State):
  return {"messages":llm.invoke(state['messages'])}

graph_builder.add_node("chatbot", chatbot)
graph_builder

# %%
graph_builder.add_edge(START, "chatbot")
graph_builder.add_edge("chatbot", END)

graph = graph_builder.compile()

# %%
from IPython.display import Image, display
try:
  display(Image(graph.get_graph().draw_mermaid_png()))
except Exception:
  pass

# %%
while True:
  user_input=input("User: ")
  if user_input.lower() in ["quit","q"]:
    print("Good Bye")
    break
  for event in graph.stream({'messages':("user",user_input)}):
    print(event.values())
    for value in event.values():
      print(value['messages'])
      print("Assistant:",value["messages"].content)
# Out:
# User:  Hello, how are you doing?
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Cell In[19], line 6
#       2   user_input=input("User: ")
#       3   if user_input.lower() in ["quit","q"]:
#       4     print("Good Bye")
#       5     break
# ----> 6   for event in graph.stream({'messages':("user",user_input)}):
#       7     print(event.values())
#       8     for value in event.values():
#       9       print(value['messages'])
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langgraph\pregel\main.py:2936, in Pregel.stream(self, input, config, context, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, durability, control, subgraphs, debug, version, **kwargs)
#    2934 for task in loop.match_cached_writes():
#    2935     loop.output_writes(task.id, task.writes, cached=True)
# -> 2936 for _ in runner.tick(
#    2937     [t for t in loop.tasks.values() if not t.writes],
#    2938     timeout=self.step_timeout,
#    2939     get_waiter=get_waiter,
#    2940     schedule_task=loop.accept_push,
#    2941 ):
#    2942     # emit output
#    2943     yield from _output(
#    2944         stream_mode,
#    2945         print_mode,
#    (...)   2951         _state_mapper,
#    2952     )
#    2953 loop.after_tick()
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langgraph\pregel\_runner.py:207, in PregelRunner.tick(self, tasks, reraise, timeout, retry_policy, get_waiter, schedule_task)
#     205 scheduled_error_handler = False
#     206 try:
# --> 207     run_with_retry(
#     208         t,
#     209         retry_policy,
#     210         configurable={
#     211             CONFIG_KEY_CALL: partial(
#     212                 _call,
#     213                 weakref.ref(t),
#     214                 retry_policy=retry_policy,
#     215                 futures=weakref.ref(futures),
#     216                 schedule_task=schedule_task,
#     217                 submit=self.submit,
#     218             ),
#     219         },
#     220     )
#     221     self.commit(t, None)
#     222 except Exception as exc:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langgraph\pregel\_retry.py:585, in run_with_retry(task, retry_policy, configurable)
#     583     task.writes.clear()
#     584     # run the task
# --> 585     return task.proc.invoke(task.input, config)
#     586 except ParentCommand as exc:
#     587     ns: str = config[CONF][CONFIG_KEY_CHECKPOINT_NS]
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langgraph\_internal\_runnable.py:684, in RunnableSeq.invoke(self, input, config, **kwargs)
#     682     # run in context
#     683     with set_config_context(config, run) as context:
# --> 684         input = context.run(step.invoke, input, config, **kwargs)
#     685 else:
#     686     input = step.invoke(input, config)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langgraph\_internal\_runnable.py:426, in RunnableCallable.invoke(self, input, config, **kwargs)
#     424         run_manager.on_chain_end(ret)
#     425 else:
# --> 426     ret = self.func(*args, **kwargs)
#     427 if self.recurse and isinstance(ret, Runnable):
#     428     return ret.invoke(input, config)
#
# Cell In[16], line 2, in chatbot(state)
#       1 def chatbot(state:State):
# ----> 2   return {"messages":llm.invoke(state['messages'])}
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_core\language_models\chat_models.py:474, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     460 @override
#     461 def invoke(
#     462     self,
#    (...)    467     **kwargs: Any,
#     468 ) -> AIMessage:
#     469     config = ensure_config(config)
#     470     return cast(
#     471         "AIMessage",
#     472         cast(
#     473             "ChatGeneration",
# --> 474             self.generate_prompt(
#     475                 [self._convert_input(input)],
#     476                 stop=stop,
#     477                 callbacks=config.get("callbacks"),
#     478                 tags=config.get("tags"),
#     479                 metadata=config.get("metadata"),
#     480                 run_name=config.get("run_name"),
#     481                 run_id=config.pop("run_id", None),
#     482                 **kwargs,
#     483             ).generations[0][0],
#     484         ).message,
#     485     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_core\language_models\chat_models.py:1823, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1814 @override
#    1815 def generate_prompt(
#    1816     self,
#    (...)   1820     **kwargs: Any,
#    1821 ) -> LLMResult:
#    1822     prompt_messages = [p.to_messages() for p in prompts]
# -> 1823     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_core\language_models\chat_models.py:1630, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1627 for i, m in enumerate(input_messages):
#    1628     try:
#    1629         results.append(
# -> 1630             self._generate_with_cache(
#    1631                 m,
#    1632                 stop=stop,
#    1633                 run_manager=run_managers[i] if run_managers else None,
#    1634                 **kwargs,
#    1635             )
#    1636         )
#    1637     except BaseException as e:
#    1638         if run_managers:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_core\language_models\chat_models.py:1970, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1968     result = generate_from_stream(iter(chunks))
#    1969 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1970     result = self._generate(
#    1971         messages, stop=stop, run_manager=run_manager, **kwargs
#    1972     )
#    1973 else:
#    1974     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\langchain_groq\chat_models.py:621, in ChatGroq._generate(self, messages, stop, run_manager, **kwargs)
#     616 message_dicts, params = self._create_message_dicts(messages, stop)
#     617 params = {
#     618     **params,
#     619     **kwargs,
#     620 }
# --> 621 response = self.client.create(messages=message_dicts, **params)
#     622 return self._create_chat_result(response, params)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\groq\resources\chat\completions.py:461, in Completions.create(self, messages, model, citation_options, compound_custom, disable_tool_validation, documents, exclude_domains, frequency_penalty, function_call, functions, include_domains, include_reasoning, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, n, parallel_tool_calls, presence_penalty, reasoning_effort, reasoning_format, response_format, search_settings, seed, service_tier, stop, store, stream, temperature, tool_choice, tools, top_logprobs, top_p, user, extra_headers, extra_query, extra_body, timeout)
#     241 def create(
#     242     self,
#     243     *,
#    (...)    300     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     301 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     302     """
#     303     Creates a model response for the given chat conversation.
#     304
#    (...)    459       timeout: Override the client-level default timeout for this request, in seconds
#     460     """
# --> 461     return self._post(
#     462         "/openai/v1/chat/completions",
#     463         body=maybe_transform(
#     464             {
#     465                 "messages": messages,
#     466                 "model": model,
#     467                 "citation_options": citation_options,
#     468                 "compound_custom": compound_custom,
#     469                 "disable_tool_validation": disable_tool_validation,
#     470                 "documents": documents,
#     471                 "exclude_domains": exclude_domains,
#     472                 "frequency_penalty": frequency_penalty,
#     473                 "function_call": function_call,
#     474                 "functions": functions,
#     475                 "include_domains": include_domains,
#     476                 "include_reasoning": include_reasoning,
#     477                 "logit_bias": logit_bias,
#     478                 "logprobs": logprobs,
#     479                 "max_completion_tokens": max_completion_tokens,
#     480                 "max_tokens": max_tokens,
#     481                 "metadata": metadata,
#     482                 "n": n,
#     483                 "parallel_tool_calls": parallel_tool_calls,
#     484                 "presence_penalty": presence_penalty,
#     485                 "reasoning_effort": reasoning_effort,
#     486                 "reasoning_format": reasoning_format,
#     487                 "response_format": response_format,
#     488                 "search_settings": search_settings,
#     489                 "seed": seed,
#     490                 "service_tier": service_tier,
#     491                 "stop": stop,
#     492                 "store": store,
#     493                 "stream": stream,
#     494                 "temperature": temperature,
#     495                 "tool_choice": tool_choice,
#     496                 "tools": tools,
#     497                 "top_logprobs": top_logprobs,
#     498                 "top_p": top_p,
#     499                 "user": user,
#     500             },
#     501             completion_create_params.CompletionCreateParams,
#     502         ),
#     503         options=make_request_options(
#     504             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     505         ),
#     506         cast_to=ChatCompletion,
#     507         stream=stream or False,
#     508         stream_cls=Stream[ChatCompletionChunk],
#     509     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\groq\_base_client.py:1242, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1228 def post(
#    1229     self,
#    1230     path: str,
#    (...)   1237     stream_cls: type[_StreamT] | None = None,
#    1238 ) -> ResponseT | _StreamT:
#    1239     opts = FinalRequestOptions.construct(
#    1240         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1241     )
# -> 1242     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\groq\_base_client.py:1044, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1041             err.response.read()
#    1043         log.debug("Re-raising status error")
# -> 1044         raise self._make_status_error_from_response(err.response) from None
#    1046     break
#    1048 assert response is not None, "could not resolve response (should never happen)"
#
# AuthenticationError: Error code: 401 - {'error': {'message': 'Invalid API Key', 'type': 'invalid_request_error', 'code': 'invalid_api_key'}}
# During task with name 'chatbot' and id '46b9360b-9895-b09a-5a1e-e4b48d5e3d31'
