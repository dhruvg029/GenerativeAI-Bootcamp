# %% [markdown]
# ### ASTRADB VectorStore
# Go from app idea to production with the AI Platform with Astra DB, the ultra-low latency database made for AI and Langflow, the low-code RAG IDE
# https://www.datastax.com/

# %%
## ASTRADB VectorStore
# !pip install \
    "langchain>=0.3.23,<0.4" \
    "langchain-core>=0.3.52,<0.4" \
    "langchain-astradb>=0.6,<0.7"
# Out:
# Requirement already satisfied: langchain<0.4,>=0.3.23 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.3.30)
# Collecting langchain-core<0.4,>=0.3.52
#   Using cached langchain_core-0.3.86-py3-none-any.whl.metadata (3.2 kB)
# Requirement already satisfied: langchain-astradb<0.7,>=0.6 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (0.6.1)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.9 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain<0.4,>=0.3.23) (0.3.11)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.17 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain<0.4,>=0.3.23) (0.8.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain<0.4,>=0.3.23) (2.13.4)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain<0.4,>=0.3.23) (2.0.50)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain<0.4,>=0.3.23) (2.32.3)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain<0.4,>=0.3.23) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<0.4,>=0.3.52) (9.1.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<0.4,>=0.3.52) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<0.4,>=0.3.52) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<0.4,>=0.3.52) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<0.4,>=0.3.52) (0.16.0)
# Requirement already satisfied: astrapy<3.0.0,>=2.0.1 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-astradb<0.7,>=0.6) (2.3.1)
# Requirement already satisfied: numpy>=2.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-astradb<0.7,>=0.6) (2.4.6)
# Requirement already satisfied: deprecation~=2.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (2.1.0)
# Requirement already satisfied: h11>=0.16.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.16.0)
# Requirement already satisfied: httpx<1,>=0.25.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.28.1)
# Requirement already satisfied: ipython>=8.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (9.14.0)
# Requirement already satisfied: pymongo>=3 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (4.17.0)
# Requirement already satisfied: toml<1.0.0,>=0.10.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.10.2)
# Requirement already satisfied: uuid6>=2024.1.12 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (2025.0.1)
# Requirement already satisfied: anyio in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (1.0.9)
# Requirement already satisfied: idna in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.25.2->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (3.17)
# Requirement already satisfied: h2<5,>=3 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (4.4.1)
# Requirement already satisfied: hyperframe<7,>=6.1 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from h2<5,>=3->httpx[http2]<1,>=0.25.2->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (4.2.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<0.4,>=0.3.52) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (1.0.0)
# Requirement already satisfied: websockets>=15.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (16.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.1.17->langchain<0.4,>=0.3.23) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3.23) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3.23) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4,>=0.3.23) (0.4.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.0.0->langchain<0.4,>=0.3.23) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests<3.0.0,>=2.0.0->langchain<0.4,>=0.3.23) (2.7.0)
# Requirement already satisfied: greenlet>=1 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain<0.4,>=0.3.23) (3.5.1)
# Requirement already satisfied: colorama>=0.4.4 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.4.6)
# Requirement already satisfied: decorator>=5.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.20.0)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.2.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (3.0.52)
# Requirement already satisfied: psutil>=7 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (7.2.2)
# Requirement already satisfied: pygments>=2.14.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (5.15.0)
# Requirement already satisfied: wcwidth in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.7.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jedi>=0.18.2->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.8.7)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pymongo>=3->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (2.8.0)
# Requirement already satisfied: executing>=1.2.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from stack_data>=0.6.0->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from stack_data>=0.6.0->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (3.0.1)
# Requirement already satisfied: pure-eval in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from stack_data>=0.6.0->ipython>=8.0.0->astrapy<3.0.0,>=2.0.1->langchain-astradb<0.7,>=0.6) (0.2.3)
# Using cached langchain_core-0.3.86-py3-none-any.whl (461 kB)
# Installing collected packages: langchain-core
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.5.3
#     Uninstalling langchain-core-1.5.3:
#       Successfully uninstalled langchain-core-1.5.3
# Successfully installed langchain-core-0.3.86
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-classic 1.0.7 requires langchain-core<2.0.0,>=1.3.3, but you have langchain-core 0.3.86 which is incompatible.
# langchain-classic 1.0.7 requires langchain-text-splitters<2.0.0,>=1.1.2, but you have langchain-text-splitters 0.3.11 which is incompatible.
# langchain-cohere 0.5.1 requires langchain-core<2.0,>=1.2.16, but you have langchain-core 0.3.86 which is incompatible.
# langchain-community 0.4.2 requires langchain-core<2.0.0,>=1.4.0, but you have langchain-core 0.3.86 which is incompatible.
# langchain-community 0.4.2 requires requests<3.0.0,>=2.32.5, but you have requests 2.32.3 which is incompatible.
# langchain-google-genai 4.2.4 requires langchain-core<2.0.0,>=1.3.2, but you have langchain-core 0.3.86 which is incompatible.
# langchain-groq 1.1.2 requires langchain-core<2.0.0,>=1.2.8, but you have langchain-core 0.3.86 which is incompatible.
# langchain-huggingface 1.2.2 requires langchain-core<2.0.0,>=1.2.31, but you have langchain-core 0.3.86 which is incompatible.
# langchain-ollama 1.1.0 requires langchain-core<2.0.0,>=1.2.21, but you have langchain-core 0.3.86 which is incompatible.
# langchain-openai 1.2.2 requires langchain-core<2.0.0,>=1.4.0, but you have langchain-core 0.3.86 which is incompatible.
# langgraph 1.2.2 requires langchain-core<2,>=1.4.0, but you have langchain-core 0.3.86 which is incompatible.
# langgraph-prebuilt 1.1.0 requires langchain-core>=1.3.1, but you have langchain-core 0.3.86 which is incompatible.
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\dhruv\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %%
# !pip install langchain_huggingface
# Out:
# Requirement already satisfied: langchain_huggingface in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (1.2.2)
# Requirement already satisfied: huggingface-hub<2.0.0,>=0.33.4 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain_huggingface) (1.17.0)
# Collecting langchain-core<2.0.0,>=1.2.31 (from langchain_huggingface)
#   Using cached langchain_core-1.5.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: tokenizers<1.0.0,>=0.19.1 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain_huggingface) (0.23.1)
# Requirement already satisfied: click>=8.4.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (8.4.1)
# Requirement already satisfied: filelock>=3.10.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.67.3)
# Requirement already satisfied: typer<0.26.0,>=0.20.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.25.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.15.0)
# Requirement already satisfied: anyio in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.13.0)
# Requirement already satisfied: certifi in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.0.9)
# Requirement already satisfied: idna in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (3.17)
# Requirement already satisfied: h11>=0.16 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.8.8)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.13.4)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (9.1.4)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.1.1)
# Requirement already satisfied: orjson>=3.9.14 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.32.3)
# Requirement already satisfied: websockets>=15.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (16.0)
# Requirement already satisfied: xxhash>=3.0.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.7.0)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (0.4.2)
# Requirement already satisfied: shellingham>=1.3.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.0.4)
# Requirement already satisfied: colorama in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from click>=8.4.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.31->langchain_huggingface) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in C:\Users\dhruv\AppData\Local\Programs\Python\Python314\Lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub<2.0.0,>=0.33.4->langchain_huggingface) (0.1.2)
# Using cached langchain_core-1.5.3-py3-none-any.whl (561 kB)
# Installing collected packages: langchain-core
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.86
#     Uninstalling langchain-core-0.3.86:
#       Successfully uninstalled langchain-core-0.3.86
# Successfully installed langchain-core-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.30 requires langchain-core<1.0.0,>=0.3.85, but you have langchain-core 1.5.3 which is incompatible.
# langchain-astradb 0.6.1 requires langchain-core<1.0.0,>=0.3.74, but you have langchain-core 1.5.3 which is incompatible.
# langchain-classic 1.0.7 requires langchain-text-splitters<2.0.0,>=1.1.2, but you have langchain-text-splitters 0.3.11 which is incompatible.
# langchain-community 0.4.2 requires requests<3.0.0,>=2.32.5, but you have requests 2.32.3 which is incompatible.
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: C:\Users\dhruv\AppData\Local\Programs\Python\Python314\python.exe -m pip install --upgrade pip

# %%
## Configure the environment variables
import os
from dotenv import load_dotenv

load_dotenv()

GROQ_API_KEY = os.getenv("GROQ_API_KEY")
ASTRA_DB_API_ENDPOINT = os.getenv("ASTRA_DB_API_ENDPOINT")
ASTRA_DB_APPLICATION_TOKEN = os.getenv("ASTRA_DB_APPLICATION_TOKEN")

# %%
from langchain_huggingface import HuggingFaceEmbeddings

## Initialize a simple HuggingFace embedding model
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

embeddings
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# HuggingFaceEmbeddings(model_name='sentence-transformers/all-MiniLM-L6-v2', cache_folder=None, model_kwargs={}, encode_kwargs={}, query_encode_kwargs={}, multi_process=False, show_progress=False)

# %%
from langchain_astradb import AstraDBVectorStore

## Create a vector store using AstraDB
vector_store = AstraDBVectorStore(
    embedding = embeddings,
    api_endpoint = ASTRA_DB_API_ENDPOINT,
    collection_name = "astra_vector_langchain",
    token = ASTRA_DB_APPLICATION_TOKEN,
    namespace = None,
)

vector_store

# %%
from langchain_core.documents import Document

## Create sample documents for the vector store
document_1 = Document(
    page_content="I had chocolate chip pancakes and scrambled eggs for breakfast this morning.",
    metadata={"source": "tweet"},
)

document_2 = Document(
    page_content="The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.",
    metadata={"source": "news"},
)

document_3 = Document(
    page_content="Building an exciting new project with LangChain - come check it out!",
    metadata={"source": "tweet"},
)

document_4 = Document(
    page_content="Robbers broke into the city bank and stole $1 million in cash.",
    metadata={"source": "news"},
)

document_5 = Document(
    page_content="Wow! That was an amazing movie. I can't wait to see it again.",
    metadata={"source": "tweet"},
)

document_6 = Document(
    page_content="Is the new iPhone worth the price? Read this review to find out.",
    metadata={"source": "website"},
)

document_7 = Document(
    page_content="The top 10 soccer players in the world right now.",
    metadata={"source": "website"},
)

document_8 = Document(
    page_content="LangGraph is the best framework for building stateful, agentic applications!",
    metadata={"source": "tweet"},
)

document_9 = Document(
    page_content="The stock market is down 500 points today due to fears of a recession.",
    metadata={"source": "news"},
)

document_10 = Document(
    page_content="I have a bad feeling I am going to get deleted :(",
    metadata={"source": "tweet"},
)

documents = [
    document_1,
    document_2,
    document_3,
    document_4,
    document_5,
    document_6,
    document_7,
    document_8,
    document_9,
    document_10,
]
documents
# Out:
# [Document(metadata={'source': 'tweet'}, page_content='I had chocolate chip pancakes and scrambled eggs for breakfast this morning.'),
#  Document(metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(metadata={'source': 'tweet'}, page_content='Building an exciting new project with LangChain - come check it out!'),
#  Document(metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.'),
#  Document(metadata={'source': 'tweet'}, page_content="Wow! That was an amazing movie. I can't wait to see it again."),
#  Document(metadata={'source': 'website'}, page_content='Is the new iPhone worth the price? Read this review to find out.'),
#  Document(metadata={'source': 'website'}, page_content='The top 10 soccer players in the world right now.'),
#  Document(metadata={'source': 'tweet'}, page_content='LangGraph is the best framework for building stateful, agentic applications!'),
#  Document(metadata={'source': 'news'}, page_content='The stock market is down 500 points today due to fears of a recession.'),
#  Document(metadata={'source': 'tweet'}, page_content='I have a bad feeling I am going to get deleted :(')]

# %%
## Add the documents to the vector store
vector_store.add_documents(documents = documents)
# Out:
# ['b804bf97d13e4488ace75c3fcfc04454',
#  '025a9b82493b4b2283548feea4e3cf28',
#  '86ccabb9e2d944589ede015096f3d6a3',
#  'e00b61094f09479a817dda0e2ed9b2a0',
#  'a4c301fedf27473f8474613765bf294c',
#  '447f1412e1f64dc58f3af156a615407c',
#  '794adf7e95024cd0871195528222e753',
#  '653c99274bee408ca8a79b1dc59b3db8',
#  'b953682dd23948818b78372a864b0042',
#  '05f1bde1bcff4ee481a6bea10f1fa20a']

# %%
## Search from Vector Store DB
vector_store.similarity_search("What is the weather?")
# Out:
# [Document(id='26e81a7e19ff45da945f3abff512ecda', metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(id='025a9b82493b4b2283548feea4e3cf28', metadata={'source': 'news'}, page_content='The weather forecast for tomorrow is cloudy and overcast, with a high of 62 degrees.'),
#  Document(id='b16c9540c2874e9f83d0144f7fa016ba', metadata={'source': 'tweet'}, page_content='I had chocolate chip pancakes and scrambled eggs for breakfast this morning.'),
#  Document(id='b804bf97d13e4488ace75c3fcfc04454', metadata={'source': 'tweet'}, page_content='I had chocolate chip pancakes and scrambled eggs for breakfast this morning.')]

# %%
## Filter the similarity search
results = vector_store.similarity_search(
    "LangChain provides abstractions to make working with LLMs easy",
    k=3,
    filter={"source": "tweet"},
)

for res in results:
    print(f'* "{res.page_content}", metadata={res.metadata}')
# Out:
# * "Building an exciting new project with LangChain - come check it out!", metadata={'source': 'tweet'}
# * "Building an exciting new project with LangChain - come check it out!", metadata={'source': 'tweet'}
# * "LangGraph is the best framework for building stateful, agentic applications!", metadata={'source': 'tweet'}

# %%
## Filter with scores in the similarity search
results = vector_store.similarity_search_with_score(
    "LangChain provides abstractions to make working with LLMs easy",
    k=3,
    filter={"source": "tweet"},
)
for res, score in results:
    print(f'* [SIM={score:.2f}] "{res.page_content}", metadata={res.metadata}')
# Out:
# * [SIM=0.79] "Building an exciting new project with LangChain - come check it out!", metadata={'source': 'tweet'}
# * [SIM=0.79] "Building an exciting new project with LangChain - come check it out!", metadata={'source': 'tweet'}
# * [SIM=0.75] "LangGraph is the best framework for building stateful, agentic applications!", metadata={'source': 'tweet'}

# %%
## Retriever
retriever=vector_store.as_retriever(
  search_type = "similarity_score_threshold",
    search_kwargs = {"k": 1, "score_threshold": 0.5},
)

retriever.invoke("Stealing from the bank is a crime", filter={"source": "news"})
# Out:
# [Document(id='1dd9a923eee748e29837f1479bb5b23f', metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.')]

# %%
## Retriever
retriever=vector_store.as_retriever(
  search_type="mmr",
    search_kwargs={"k": 1},
)
retriever.invoke("Stealing from the bank is a crime", filter={"source": "news"})
# Out:
# [Document(id='1dd9a923eee748e29837f1479bb5b23f', metadata={'source': 'news'}, page_content='Robbers broke into the city bank and stole $1 million in cash.')]
