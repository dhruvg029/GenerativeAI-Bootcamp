# %% [markdown]
# ### Hugging Face x LangChain : A new partner package in LangChain
# langchain_huggingface, a partner package in LangChain jointly maintained by Hugging Face and LangChain. This new Python package is designed to bring the power of the latest development of Hugging Face into LangChain and keep it up to date.

# %%
import os
from dotenv import load_dotenv
load_dotenv()

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### HuggingFaceEndpoint
# #### How to Access HuggingFace Models with API
# There are also two ways to use this class. You can specify the model with the repo_id parameter. Those endpoints use the serverless API, which is particularly beneficial to people using pro accounts or enterprise hub. Still, regular users can already have access to a fair amount of request by connecting with their HF token in the environment where they are executing the code.

# %%
from langchain_huggingface import HuggingFaceEndpoint
import os

## Get the repository for getting the API
repo_id = "google/gemma-2-2b"

## Get the LLM
llm = HuggingFaceEndpoint(
    repo_id = repo_id,
    max_new_tokens = 150,
    temperature = 0.7,
    huggingfacehub_api_token=os.getenv("HF_TOKEN")
)

## Get the response from the LLM
response = llm.invoke("What is machine learning")
print(response)
# Out:
# ?
#
# Machine learning is a subsetocial sciencethat allows computers to learn from examples and then apply this learning to new inputs. In other words, machine learning is a technique that enables computers to learn from experience.
#
# Machine learning is also known as statistical learning, statistical learning, or statistical learning. It is a field of computer science that focuses on the development of algorithms and systems that can automatically learn from data and make predictions or decisions without being explicitly programmed.
#
# It is a branch of computer science that deals with the study of how computers can be programmed to learn from data and make predictions or decisions without being explicitly programmed.
#
# Machineocial scienceis a subfield of machine learning that focuses on building algorithms and systems that can learn from

# %%
llm.invoke("What is generative AI?")
# Out:
# '2023?\n\nGenerative AI is a set of technologies that help us create new content by using our own words, or by using our own data to train the software. For example, it can be used to create new images or text based, or to generate new music or videos.\n\nWhat are the benefits of using generative AI?\n\nThe main benefit of generative AI is that it helps us save time and money. It can be used to create new content quickly and easily, without the need for human input. This can be useful for businesses, as it allows them to create new content without having to invest in expensive human resources. It can also be used to create new products or services, without having to invest in new'

# %%
from langchain_classic import PromptTemplate, LLMChain

## Get the prompt template
template="""
Question:{question}
Answer:Lets think step by step.
"""

prompt = PromptTemplate(
    template = template, 
    input_variables = ["question"]
)

print('Prompt:', prompt)

llm_chain = LLMChain(llm = llm, prompt = prompt)
llm.invoke("Who won the cricket World up 2011")
# Out:
# Prompt: input_variables=['question'] input_types={} partial_variables={} template='\nQuestion:{question}\nAnswer:Lets think step by step.\n'
# '?\n\nWhat is the capital of New Zealand?\n\nWho won the World Cup 2007?\n\nWhat is the capital of New Zealand?\n\nWho won the cricket World Cup 2011?\n\nWho won the Cricket World Cup  2011?\n\nWho won the cricket World Cup in 2011?\n\nWho won the cricket World Cup in 2011?\n\nWho won the World Cup in 2011?\n\nWho won the World Cup in 2011?\n\nWho won the World Cup in 2011?\n\nWho won the World Cup in 2011?\n\nWho won the World Cup in 20'

# %%
from langchain_community.embeddings import HuggingFaceBgeEmbeddings

## Get the hugginggface embeddings
model_name = "BAAI/bge-small-en"
model_kwargs = {"device": "cpu"}
encode_kwargs = {"normalize_embeddings": True}
hf = HuggingFaceBgeEmbeddings(
    model_name = model_name, model_kwargs = model_kwargs, encode_kwargs = encode_kwargs
)

embedding = hf.embed_query("hi this is harrison")
embedding
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_6800\4267537664.py:6: LangChainDeprecationWarning: The class `HuggingFaceBgeEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the `langchain-huggingface package and should be used instead. To use it run `pip install -U `langchain-huggingface` and import as `from `langchain_huggingface import HuggingFaceEmbeddings``.
#   hf = HuggingFaceBgeEmbeddings(
# Loading weights: 100%|██████████| 199/199 [00:00<00:00,